# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('CompleteDataset.csv')
data.head(10)
# Out:
#    Unnamed: 0                 name   id  nametype  recclass  mass (g)  fall  \
# 0           0               Aachen    1         1       301      21.0     0
# 1           1               Aarhus    2         1       176     720.0     0
# 2           2                 Abee    6         1        77  107000.0     0
# 3           3             Acapulco   10         1         0    1914.0     0
# 4           4              Achiras  370         1       307     780.0     0
# 5           5             Adhi Kot  379         1        77    4239.0     0
# 6           6  Adzhi-Bogdo (stone)  390         1       319     910.0     0
# 7           7                 Agen  392         1       169   30000.0     0
# 8           8               Aguada  398         1       307    1620.0     0
# 9           9        Aguila Blanca  417         1       222    1440.0     0
#
#                      year    reclat    reclong           GeoLocation  \
# ...
